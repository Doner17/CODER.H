# %% [markdown]
# ![ima.png](data:image/png;base64,...)
#
# <div style="border: 2px solid #3f5edf; border-radius: 10px; background-color: #3f5edf; padding: 20px; text-align: center;">
#
#   <!-- Agrega un ícono relacionado con finanzas -->
#   📈
#
#   <h2 style="color: #f1f3fd; font-weight: bold;">
#     Perspectivas y Predicciones del Precio de Acciones de Apple: Un Estudio Analítico
#   </h2>
#
#   <!-- Agrega una descripción breve del contenido -->
#   <p style="color: #f1f3fd; font-size: 16px;">
#     Descubre análisis detallados y predicciones sobre el comportamiento futuro del precio de las acciones de Apple en este estudio analítico.
#   </p>
# </div>

# %% [markdown]
# <div style="border: 2px solid #3f5edf; border-radius: 10px; background-color: #3f5edf ; padding: 10px;">
#   <h2 style="color: #f1f3fd; font-weight: bold;">
#     INTRODUCCIÓN ♟
#   </h2>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
# <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px">Abstrac</h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Este proyecto busca predecir el precio futuro de las acciones de Apple mediante el análisis de datos históricos de los últimos 10 años y diversas variables influyentes. Se centra en la relevancia de Apple en el sector tecnológico y su impacto en los mercados financieros. El análisis está dirigido a inversores y profesionales financieros en busca de decisiones informadas, evaluando la relación entre el precio de las acciones de Apple y factores clave como el rendimiento de otras grandes empresas tecnológicas, el índice VIX y los bonos de EE. UU. a 2 y 30 años. Se consideran eventos macroeconómicos y tecnológicos que han influido en la valoración de las acciones de Apple en la última década. Aunque las proyecciones se basan en datos históricos y no garantizan resultados precisos, este proyecto proporciona información valiosa para inversores y profesionales financieros interesados en estrategias de inversión informadas, advirtiendo sobre la imprevisibilidad de los mercados financieros y la posible influencia de eventos inesperados en las proyecciones.
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
# <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px">Contexto Comercial</h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Apple, Inc. fundada en 1976 por Steve Jobs, Steve Wozniak y Ronald Wayne, es un gigante tecnológico global que ha revolucionado la industria con productos icónicos como el iPhone, iPad y MacBook. Su enfoque en la innovación, diseño elegante y experiencia de usuario ha posicionado a Apple como líder en tecnología de consumo y ha influido en la cultura digital. La marca representa estatus y calidad, generando una base de clientes leales. Además, su sólida presencia en el mercado bursátil y su constante desarrollo tecnológico han convertido a Apple en una referencia crucial en la economía global y en el sector tecnológico.
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
# <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px">Problema</h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# El problema de investigación que motiva este estudio radica en la complejidad y la volatilidad inherente a los mercados financieros, especialmente en relación con la proyección del precio de las acciones. A pesar de los esfuerzos por desarrollar modelos predictivos y utilizar variables clave, la incertidumbre persiste. La falta de claridad sobre cómo influirán factores como el rendimiento de otras empresas tecnológicas, la volatilidad del mercado y los cambios en los rendimientos de bonos de EE. UU. en el precio de las acciones de Apple representa un desafío significativo para los inversores y analistas. Esta investigación busca abordar esta problemática al identificar patrones históricos y relaciones entre variables para mejorar la capacidad de proyección y toma de decisiones en el ámbito financiero.
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
# <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px">Objetivo</h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# El objetivo de esta investigación es estimar el precio de cierre de la acción de Apple a partir de diferentes variables, como las acciones de Microsoft, Samsung y Google, quienes son competidores directos de Apple. Cualquier situación o acción que realice la competencia puede afectar al precio de Apple. Se espera que estos competidores tengan una correlación positiva con respecto a Apple. También se considera el índice VIX, que corresponde al índice de volatilidad del mercado de opciones PUT de Chicago. Por último, se consideran los bonos a 2 y 30 años de EEUU, ya que están implicitamente asociados a la inflación del país debido a que están relacionados con una tasa de interés. Dependiendo de la rentabilidad que ofrezcan estos bonos, pueden impactar en el mercado bursátil, pasando de renta variable a renta fija. Es decir, se espera que tengan una correlación negativa.
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
# <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px">Cliente-Usuario</h2>
#   <p style="text-align: justify; font-size: 12px; color: black">El cliente de esta investigación es un fondo de inversión privado especializado en operación put y call en acciones, índices y commodities. El usuario de este estudio es un experimentado portfolio manager quien lo empleará como una herramienta extra para la toma de decisiones en transacciones de la acción de Apple.
#
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">
#     Dataset
#   </h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
#     El dataset corresponde a datos de Apple, Microsoft, Samsung, Google, VIX, Bono de EEUU a 2 años y a 30 años,  de los últimos 10 años, de los cuales solo corresponden a fechas que están presentes para todos, es decir, si una acción no estuvo en cotización en un día, se eliminó dicha fecha para todos los demás.
#     Donde:
#   </p>
#   <ul style="text-align: justify; font-size: 12px; color: black;">
#     <li style="font-size: 12px; color: black;">x = (a: apple, m: microsoft, s: Samsung, g: Google, v: VIX, 2: Bono de EEUU a 2 años, 30: Bono de EEUU a 30 años)</li>
#     <li style="font-size: 12px; color: black;">Open_x: corresponde a precio de apertura del instrumento x</li>
#     <li style="font-size: 12px; color: black;">High_x: Corresponde a precio más alto del del instrumento x.</li>
#     <li style="font-size: 12px; color: black;">Low_x: Corresponde a precio más bajo del instrumento x.</li>
#     <li style="font-size: 12px; color: black;">Close_x: Corresponde a precio de cierre del instrumento x.</li>
#     <li style="font-size: 12px; color: black;">Adj Close_x: Corresponde a precio de cierre ajustado por el empresa o institución del instrumento x.</li>
#     <li style="font-size: 12px; color: black;">Volumen_x: Corresponde al volumen transado del instrumento x.</li>
#     <li style="font-size: 12px; color: black;">% var_x: Corresponde a la variación porcentual de precio de cierre del instrumento x.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">
#     Hipótesis
#   </h2>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Las hipótesis planteadas a continuación tiene como objetivo dar orientación y guía esta investigación, la cual son las siguientes:
#   </p>
#
# <ul style="text-align: justify; font-size: 12px; color: black;">
#     <li style="font-size: 12px; color: black;">Las variables elegidas para realizar la estimación en este proyecto tienen una correlación superior al 60%.</li>
#     <li style="font-size: 12px; color: black;">Apple es la compañía con más volumen transado en el mercado bursátil.</li>
#     <li style="font-size: 12px; color: black;">Existe una correlación positiva superior al 0.7 entre GOOGLE Y APPLE.</li>
#     <li style="font-size: 12px; color: black;">Apple tiene el precio de cierre histórico más alto de frente a GOOGLE, Microsoft, Samsung, Intel y el índice VIX.</li>
#     <li style="font-size: 12px; color: black;">La moda de Apple se encuentra entre USD 0 y USD 50.</li>
#   </ul>
#   <p style="text-align: justify; font-size: 12px; color: black;">
# A través del análisis exploratorio se buscará dar respuesta a las hipótesis planteadas.
#   </p>

# %% [markdown]
# <div style="border: 2px solid #3f5edf; border-radius: 10px; background-color: #3f5edf ; padding: 10px;">
#   <h2 style="color: #f1f3fd; font-weight: bold;">
#     DATA WRANGLING 🧹🗑
#   </h2>
# </div>

# %% [markdown]
# <div style="text-align:center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# La data fue extraida de Yahoo Finance, en formato csv, de los último 10 años. Un desafío en la manipulación de esto dato fue la "**fecha**" debido a que es común que hay día(s) que suspenden su cotización en bolsa por algún factor externo o interno, como ocurrío en el black monday en el 2020.
# Entonces, el proceso consiste en enlazar los archivos de las x variables en un solo df, como variable en común, la fecha:
#
#   </p>
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import glob
import os

# Lista de archivos CSV y Excel
file_patterns =  ["/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/005930.KS.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/AAPL.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/MSFT.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/GOOG.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/^VIX.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/Estados Unidos 2 años Información Histórica Rendimiento Bono.csv",
                 "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/Estados Unidos 30 años Datos Históricos Rendimiento de Bonos.csv"
                 ]

# Crear una lista para almacenar los DataFrames individuales
dfs = []

# Iterar a través de los patrones de archivo
for pattern in file_patterns:
    # Obtener una lista de rutas de archivos que coincidan con el patrón
    file_paths = glob.glob(pattern)

    # Iterar a través de las rutas de archivos encontradas
    for file_path in file_paths:
        # Leer archivos CSV
        if file_path.endswith('.csv'):
            df = pd.read_csv(file_path)

            # Renombrar la columna 'Date' a 'Fecha' si existe
            if 'Date' in df.columns:
                df.rename(columns={'Date': 'Fecha'}, inplace=True)

            # Convertir la columna 'Fecha' a tipo datetime
            df['Fecha'] = pd.to_datetime(df['Fecha'])

            # Realizar detección de nulos y mostrar resultados
            null_counts = df.isnull().sum()
            print(f"Detección de nulos en {file_path}:\n{null_counts}\n")

            # Mostrar estadísticas descriptivas
            describe_stats = df.describe()
            print(f"Estadísticas descriptivas en {file_path}:\n{describe_stats}\n")

        # Leer archivos Excel
        elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
            df = pd.read_excel(file_path)

            # Continuar si no hay una columna 'Fecha'
            if 'Fecha' not in df.columns:
                continue

            # Convertir la columna 'Fecha' al formato correcto
            df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d.%m.%Y')

            # Realizar detección de nulos y mostrar resultados
            null_counts = df.isnull().sum()
            print(f"Detección de nulos en {file_path}:\n{null_counts}\n")

            # Mostrar estadísticas descriptivas
            describe_stats = df.describe()
            print(f"Estadísticas descriptivas en {file_path}:\n{describe_stats}\n")

        # Agregar el DataFrame a la lista
        dfs.append(df)

# Combinar los dataframes en uno solo basado en las fechas
df_combinado = dfs[0]
for i in range(1, len(dfs)):
    df_combinado = pd.merge(df_combinado, dfs[i], on='Fecha', how='inner')

# Ruta y nombre del archivo de destino
output_folder = '/content'
file_name = 'Apple y sus variables.xlsx'

# Construir la ruta completa del archivo
output_path = os.path.join(output_folder, file_name)

# Guardar el archivo de Excel temporalmente
df_combinado.to_excel(output_path, index=False)
# Out:
# Detección de nulos en /content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/005930.KS.csv:
# Fecha        0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Estadísticas descriptivas en /content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/005930.KS.csv:
#                Open          High           Low         Close     Adj Close  \
# count   2457.000000   2457.000000   2457.000000   2457.000000   2457.000000
# mean   46838.461538  47264.700855  46396.332926  46820.264550  42467.244021
# std    17952.575217  18086.109104  17802.067562  17926.254215  18813.403169
# min    21360.000000  21480.000000  20660.000000  21340.000000  17507.330078
# 25%    28260.000000  28560.000000  28020.000000  28260.000000  22913.583984
# 50%    46460.000000  46900.000000  46000.000000  46450.000000  40816.347656
# ...

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Al analizar la detección de nulos, se observó que el índice VIX tiene datos faltante (92). no obstante, al unir los data set. se eliminan filas que no cumplen con el requisito que se transen el mismo día.
# De esa forma, se logró enlazar los archivos en base a la fechas, es decir, quedan solo las fechas que todas las acciones, los bonos y el índice VIX cotizó en bolsa el mismo día, eliminando las anomalías propias de cada instrumento que suspendió su cotización o entregó dividendos. En el nuevo df la columna completa tiene un valor de 0, por lo tanto, se va a eliminar porque no va a incidir en el análisis.
# Además, se va a combiar el nombre de las columnas y el cambiar el formato de "% var_2 y % var_30" a uno con números décimales, al igual que todas las otras variables.
#   </p>
# </div>

# %%
import pandas as pd
import glob
import os

# Lista de archivos CSV y Excel
file_patterns = [
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/005930.KS.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/AAPL.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/GOOG.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/MSFT.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/^VIX.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/Estados Unidos 2 años Información Histórica Rendimiento Bono.csv",
    "/content/drive/MyDrive/Data Science-CODER/DESAFIOS/Desafío de visualización /VARIABLES/Estados Unidos 30 años Datos Históricos Rendimiento de Bonos.csv"
]

# Leer cada archivo y cargarlo en un DataFrame
dfs = []
for pattern in file_patterns:
    file_paths = glob.glob(pattern)
    for file_path in file_paths:
        if file_path.endswith('.csv'):
            df = pd.read_csv(file_path)
            if 'Date' in df.columns:
                df.rename(columns={'Date': 'Fecha'}, inplace=True)
            df['Fecha'] = pd.to_datetime(df['Fecha'])
        elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
            df = pd.read_excel(file_path)
            if 'Fecha' not in df.columns:
                continue
            df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d.%m.%Y')
        dfs.append(df)

# Combinar los DataFrames en uno solo
df_combinado = dfs[0]
for i in range(1, len(dfs)):
    df_combinado = pd.merge(df_combinado, dfs[i], on='Fecha', how='inner')

# Eliminar la columna número 31
df_combinado = df_combinado.drop(columns=[df_combinado.columns[30]])

# Cambiar los nombres de las columnas según el orden proporcionado
new_column_names = [
    "Fecha", "Open_s", "High_s", "Low_s", "Close_s", "Adj Close_s", "Volume_s",
    "Open_a", "High_a", "Low_a", "Close_a", "Adj Close_a", "Volume_a",
    "Open_m", "High_m", "Low_m", "Close_m", "Adj Close_m", "Volume_m",
    "Open_g", "High_g", "Low_g", "Close_g", "Adj Close_g", "Volume_g",
    "Open_v", "High_v", "Low_v", "Close_v", "Adj Close_v",
    "Close_2", "Open_2", "High_2", "Low_2", "% var_2",
    "Close_30", "Open_30", "High_30", "Low_30", "% var_30",
]

# Cambiar los nombres de las columnas en el DataFrame
df_combinado.columns = new_column_names

# Modificar el formato de las columnas % var_2 y % var_30
df_combinado['% var_2'] = df_combinado['% var_2'].str.replace(',', '.').str.rstrip('%').astype(float) / 100
df_combinado['% var_30'] = df_combinado['% var_30'].str.replace(',', '.').str.rstrip('%').astype(float) / 100

# Ruta y nombre del archivo de destino
output_folder = '/content'
file_name = 'Apple y sus variable2.xlsx'

# Construir la ruta completa del archivo
output_path = os.path.join(output_folder, file_name)

# Guardar el archivo de Excel
df_combinado.to_excel(output_path, index=False)

# Imprimir la ruta del archivo
print("El archivo se ha guardado en:", output_path)

df_combinado = pd.merge(df_combinado, dfs[i], on='Fecha', how='inner', suffixes=('', ''))
# Out:
# <ipython-input-4-56ac79f9dd19>:25: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Fecha'] = pd.to_datetime(df['Fecha'])
# <ipython-input-4-56ac79f9dd19>:25: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Fecha'] = pd.to_datetime(df['Fecha'])
# <ipython-input-4-56ac79f9dd19>:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Low_x', 'Adj Close_x', 'Open_x', 'Volume_x', 'High_x', 'Close_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_combinado = pd.merge(df_combinado, dfs[i], on='Fecha', how='inner')
# El archivo se ha guardado en: /content/Apple y sus variable2.xlsx

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Debido a la unión de los data set y cambio de nombre, se produjo una duplicidad de columnas ['Último', 'Apertura', 'Máximo', 'Mínimo', '% var.'], las cuales se procederá a eliminar.
#   </p>
# </div>

# %%
# Eliminar las columnas especificadas
columnas_a_eliminar = ['Último', 'Apertura', 'Máximo', 'Mínimo', '% var.']
df_combinado = df_combinado.drop(columns=columnas_a_eliminar)

# %%
import pandas as pd

# Suponiendo que df_combinado es tu DataFrame actual
# Columnas a modificar
columns_to_modify = ['Close_30', 'Open_30', 'High_30', 'Low_30']

# Iterar sobre las columnas y cambiar el formato
for col in columns_to_modify:
    df_combinado[col] = df_combinado[col].str.replace(',', '.')

# %% [markdown]
# <div style="border: 2px solid #3f5edf; border-radius: 10px; background-color: #3f5edf ; padding: 10px;">
#   <h2 style="color: #f1f3fd; font-weight: bold;">
#     API de Yahoo Finance 📊
#
#
#   </h2>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# A continuación se empleó la librería de Yahoo finance, similar a una api, la cual se puede obtener diversos datos financieros e ir actualizandose casi de manera autómaticas según sea los requirimientos.
# En en este caso, se extraerán las cotizaciones de Intel debido que es una empresa de interés que puede tener impacto en las acciones de Apple.
#   </p>
# </div>

# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Definición del símbolo de la acción
symbol = "INTC"

# Define las fechas de inicio y finalización del historial
start_date = "2013-07-15"
end_date = "2023-07-15"

# Crea un objeto Ticker para el símbolo especificado
ticker = yf.Ticker(symbol)

# Obtiene el historial de precios en el rango de fechas especificado
historical_data = ticker.history(period="1d", start=start_date, end=end_date)

# Reinicia el índice y luego cambia el nombre de la columna de índice a "Fecha"
historical_data = historical_data.reset_index()
historical_data.rename(columns={'Date': 'Fecha'}, inplace=True)

# Ajustar el formato de la columna "Fecha" eliminando la hora
historical_data['Fecha'] = historical_data['Fecha'].dt.strftime('%Y-%m-%d')

# Cambia los nombres de las columnas
historical_data.rename(columns={'Open': 'Open_i', 'High': 'High_i', 'Low': 'Low_i', 'Close': 'Close_i', 'Volume': 'Volume_i'}, inplace=True)

# Elimina las columnas "Dividends" y "Stock Splits" del DataFrame
historical_data = historical_data.drop(["Dividends", "Stock Splits"], axis=1)

# %%
historical_data['Fecha'] = pd.to_datetime(historical_data['Fecha'])
df_combinado = pd.merge(df_combinado, historical_data, on='Fecha', how='inner', suffixes=('_df_combinado', '_historical_data'))

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Existe un problema con el formato de  "Close_30", lo cual se procede a modificar.
#   </p>
# </div>

# %%
# Convertir 'Close_30' a tipo numérico, y manejar valores no numéricos como 'NaN'
df_combinado['Close_30'] = pd.to_numeric(df_combinado['Close_30'], errors='coerce')

# Calcular la matriz de correlación
columnas_interes = ['Close_s', 'Close_a', 'Close_g', 'Close_m', 'Close_v', 'Close_2', 'Close_30', 'Close_i']
df_interes = df_combinado[columnas_interes]

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# De esta forma, se intregró la API de Yahoo finance con el df que se estaba trabajando anteriormente.
#   </p>
# </div>

# %% [markdown]
# <div style="border: 2px solid #3f5edf; border-radius: 10px; background-color: #3f5edf ; padding: 10px;">
#   <h2 style="color: #f1f3fd; font-weight: bold;">
#     ANÁLISIS EXPLORATORIO &#x1F50D;
#
#   </h2>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Luego de realizar el Data Wrangling, se da pie a en el análisis exploratorio (EDA) donde se examina datos revelando patrones, distribuciones y tendencias, ofreciendo insights iniciales para futuros enfoques, en la cual se presentarán algunas hipótesis al respecto.
#   </p>
# </div>

# %%
import pandas as pd

# Cargar el dataset
df = df_combinado

# Verificar si hay datos nulos
datos_faltantes = df.isnull().sum()

# Mostrar la cantidad de datos faltantes por columna
print(datos_faltantes)
# Out:
# Fecha          0
# Open_s         0
# High_s         0
# Low_s          0
# Close_s        0
# Adj Close_s    0
# Volume_s       0
# Open_a         0
# High_a         0
# Low_a          0
# Close_a        0
# Adj Close_a    0
# Volume_a       0
# Open_m         0
# High_m         0
# Low_m          0
# Close_m        0
# Adj Close_m    0
# Volume_m       0
# Open_g         0
# High_g         0
# Low_g          0
# Close_g        0
# Adj Close_g    0
# Volume_g       0
# Open_v         0
# High_v         0
# Low_v          0
# Close_v        0
# Adj Close_v    0
# Close_2        0
# Open_2         0
# High_2         0
# Low_2          0
# % var_2        0
# Close_30       0
# Open_30        0
# High_30        0
# Low_30         0
# % var_30       0
# Open_i         0
# High_i         0
# Low_i          0
# Close_i        0
# Volume_i       0
# dtype: int64

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# En base al contexto comercial y noticias financiera, Apple es la compañia con más volumen transado en el mercado bursatil y en su efecto, más que Samsung, Google, Microsoft e INTEL. A través de de los siguientes dos gráfico se podrá demostrar o desistir de lo postulado.
#   </p>
# </div>

# %%
# !pip install plotly

# %%
pip install ipywidgets

# %%
import pandas as pd
import plotly.graph_objects as go

# Leer los datos de las acciones en una fecha determinada
df = df_combinado

# Filtrar los datos para la fecha deseada
fecha_deseada = '2023-05-10'
df_fecha = df[df['Fecha'] == fecha_deseada]

# Datos de volumen transado para las acciones y fecha seleccionada
volumen = [df['Volume_s'][0], df['Volume_a'][0], df['Volume_g'][0], df['Volume_m'][0], df['Volume_i'][0]]
acciones = ['Samsung', 'Apple', 'Google', 'Microsoft', 'INTEL']

# Crear el gráfico de barras interactivo con Plotly
fig = go.Figure()
fig.add_trace(go.Bar(x=acciones, y=volumen, marker_color=['#14299f', '#000000', '#ea4335', '#1093eb', '#0071C5']))

# Personalizar el diseño del gráfico
fig.update_layout(
    title={
        'text': f'<b>Volumen transado por acción - Fecha: {fecha_deseada}</b>',
        'x': 0.5,  # Alineación horizontal central
        'y': 0.95,  # Posición vertical superior del título
        'font': {'color': '#3f5edf'}  # Color del título
    },
    xaxis_title='Acciones',
    yaxis_title='Volumen',
)

# Mostrar el gráfico interactivo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: #3f5edf;">
#     <b>En este gráfico de barra se puede apreciar los volúmenes transados en una fecha determinada de la competencia de Apple, donde se puede inferir que si bien, Samsung es un competidor directo, específicamente en el mercado de los Smartphone, puede que no incida en gran medida como Google, Microsoft o INTEL.</b>
#   </p>
# </div>

# %%
import pandas as pd
import plotly.graph_objects as go

# Leer los datos de las acciones
df = df_combinado

# Filtrar los datos para el año 2023
df_2023 = df[df['Fecha'].dt.year == 2023]

# Obtener el volumen transado para cada acción en el año 2023
volumen_2023 = [df_2023['Volume_s'].sum(), df_2023['Volume_a'].sum(), df_2023['Volume_g'].sum(), df_2023['Volume_m'].sum(), df_2023['Volume_i'].sum()]
acciones = ['Samsung', 'Apple', 'Google', 'Microsoft', 'INTEL']

# Definir los colores para cada porción del gráfico
colores = ['#14299f', '#000000', '#ea4335', '#1093eb', '#0071C5']

# Crear el gráfico de torta interactivo con Plotly
fig = go.Figure()
fig.add_trace(go.Pie(
    labels=acciones,
    values=volumen_2023,
    textinfo='percent+label',
    marker=dict(colors=colores),
))

# Personalizar el diseño del gráfico y aumentar el tamaño
fig.update_layout(
    title=dict(
        text='<b>Volumen transado en el año 2023</b>',
        x=0.5,  # Alineación horizontal central
        y=0.95,  # Posición vertical superior del título
        font=dict(
            color='#3f5edf'  # Color del título
        )
    ),
    width=800,  # Ancho de la figura
    height=600  # Alto de la figura
)

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: #3f5edf;">
#     <b>En este gráfico de torta es más ilustrativo, el volumen de acciones transadas este 2023, donde se aprecia que el menor volumen transado en dicho año es de Samsung, a pesar que es en terminos de dólares, el precio de la acción Samsung es la más barata (aproximadamente unos USD 56, que equivalen a KRW 70.917). Entonces se podría mantener la hipótesis anterior, que tal ves no tenga un gran impacto en el precio de la acción, no obstante, este tipo de gráfico puede demostrar que quizás si tenga una significacia en el precio de la acción de Apple. E INTEL toma bastante relevancia como una variable pueda tener influencia en el precio de Apple.</b>
#   </p>
# </div>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import HTML, display

# Crear un DataFrame vacío para almacenar los resultados
resultados_df = pd.DataFrame(columns=["Compañía", "t-Estadístico", "Valor p", "Resultado"])

# Test de hipótesis 1: Apple vs. Samsung
X = df_combinado["Volume_a"].values
S = df_combinado["Volume_s"].values

media_apple = np.mean(X)
media_samsung = np.mean(S)

t_statistic, p_value = stats.ttest_ind(X, S)

alfa = 0.05

if t_statistic > 0 and p_value < alfa:
    resultado = "El volumen de Apple es mayor que el de Samsung (p < 0.05). Se rechaza la hipótesis nula (H0)."
elif t_statistic < 0 and p_value < alfa:
    resultado = "El volumen de Samsung es mayor que el de Apple (p < 0.05). Se rechaza la hipótesis nula (H0)."
else:
    resultado = "No hay evidencia suficiente para concluir que un volumen es mayor que el otro. No se rechaza la hipótesis nula (H0)."

nuevo_resultado = {"Compañía": "Samsung", "t-Estadístico": t_statistic, "Valor p": p_value, "Resultado": resultado}
resultados_df = pd.concat([resultados_df, pd.DataFrame([nuevo_resultado])], ignore_index=True)

# Test de hipótesis 2: Apple vs. Google
X = df_combinado["Volume_a"].values
G = df_combinado["Volume_g"].values

media_apple = np.mean(X)
media_google = np.mean(G)

t_statistic, p_value = stats.ttest_ind(X, G)

if t_statistic > 0 and p_value < alfa:
    resultado = "El volumen de Apple es mayor que el de Google (p < 0.05). Se rechaza la hipótesis nula (H0)."
elif t_statistic < 0 and p_value < alfa:
    resultado = "El volumen de Google es mayor que el de Apple (p < 0.05). Se rechaza la hipótesis nula (H0)."
else:
    resultado = "No hay evidencia suficiente para concluir que un volumen es mayor que el otro. No se rechaza la hipótesis nula (H0)."

nuevo_resultado = {"Compañía": "Google", "t-Estadístico": t_statistic, "Valor p": p_value, "Resultado": resultado}
resultados_df = pd.concat([resultados_df, pd.DataFrame([nuevo_resultado])], ignore_index=True)

# Test de hipótesis 3: Apple vs. Microsoft
X = df_combinado["Volume_a"].values
M = df_combinado["Volume_m"].values

media_apple = np.mean(X)
media_microsoft = np.mean(M)

t_statistic, p_value = stats.ttest_ind(X, M)

if t_statistic > 0 and p_value < alfa:
    resultado = "El volumen de Apple es mayor que el de Microsoft (p < 0.05). Se rechaza la hipótesis nula (H0)."
elif t_statistic < 0 and p_value < alfa:
    resultado = "El volumen de Microsoft es mayor que el de Apple (p < 0.05). Se rechaza la hipótesis nula (H0)."
else:
    resultado = "No hay evidencia suficiente para concluir que un volumen es mayor que el otro. No se rechaza la hipótesis nula (H0)."

nuevo_resultado = {"Compañía": "Microsoft", "t-Estadístico": t_statistic, "Valor p": p_value, "Resultado": resultado}
resultados_df = pd.concat([resultados_df, pd.DataFrame([nuevo_resultado])], ignore_index=True)

# Test de hipótesis 4: Apple vs. INTEL
X = df_combinado["Volume_a"].values
I = df_combinado["Volume_i"].values

media_apple = np.mean(X)
media_intel = np.mean(I)

t_statistic, p_value = stats.ttest_ind(X, I)

if t_statistic > 0 and p_value < alfa:
    resultado = "El volumen de Apple es mayor que el de INTEL (p < 0.05). Se rechaza la hipótesis nula (H0)."
elif t_statistic < 0 and p_value < alfa:
    resultado = "El volumen de INTEL es mayor que el de Apple (p < 0.05). Se rechaza la hipótesis nula (H0)."
else:
    resultado = "No hay evidencia suficiente para concluir que un volumen es mayor que el otro. No se rechaza la hipótesis nula (H0)."

nuevo_resultado = {"Compañía": "INTEL", "t-Estadístico": t_statistic, "Valor p": p_value, "Resultado": resultado}
resultados_df = pd.concat([resultados_df, pd.DataFrame([nuevo_resultado])], ignore_index=True)

# Formatear el código HTML con el estilo proporcionado
styled_html = f'''
<div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
  <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Apple es la compañía con más volumen transado en el mercado bursátil.</h2>
  {resultados_df.to_html(classes='table-bordered', escape=False, index=False).replace('<th>Compañía</th>', '<th style="color: #3f5edf;">Compañía</th>').replace('<th>t-Estadístico</th>', '<th style="color: #3f5edf;">t-Estadístico</th>').replace('<th>Valor p</th>', '<th style="color: #3f5edf;">Valor p</th>').replace('<th>Resultado</th>', '<th style="color: #3f5edf;">Resultado</th>')}
</div>
'''

# Mostrar la tabla en el notebook
display(HTML(styled_html))
# Out:
# <div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
#   <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Apple es la compañía con más volumen transado en el mercado bursátil.</h2>
#   <table border="1" class="dataframe table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="color: #3f5edf;">Compañía</th>
#       <th style="color: #3f5edf;">t-Estadístico</th>
#       <th style="color: #3f5edf;">Valor p</th>
#       <th style="color: #3f5edf;">Resultado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Samsung</td>
#       <td>65.238752</td>
#       <td>0.0</td>
#       <td>El volumen de Apple es mayor que el de Samsung (p < 0.05). Se rechaza la hipótesis nula (H0).</td>
#     </tr>
#     <tr>
#       <td>Google</td>
#       <td>56.079636</td>
#       <td>0.0</td>
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar solo las columnas de interés
selected_columns = ['Close_s', 'Close_a', 'Close_g', 'Close_m', 'Close_v', 'Close_2', 'Close_30', 'Close_i']
df_selectedc = df_combinado[selected_columns]

# Crear una lista con las etiquetas
labels = ['Samsung', 'Apple', 'Google', 'Microsoft', 'VIX', 'Bono EEUU a 2 años', 'Bono EEUU a 30 años', 'INTEL']

# Calcular la matriz de correlación
correlation_matrix = df_selectedc.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(10, 8))

# Crear el mapa de calor
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", xticklabels=labels, yticklabels=labels)

# Configurar el título
plt.title('Matriz de Correlación', color='#3f5edf', fontsize=16, pad=20)  # Color y centrado

# Mostrar el mapa de calor
plt.show()

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: #3f5edf;">
#     <b>Esta matriz de correlación se pueden obtener bastantes análisis;
# Que efectivamente existe una correlación positiva y bastante fuerte entre los competidores de Apple, en especial con GOOGLE, Samsung y Microsoft.
# Exite una correlación negativa con el bono a 30 años de EEUU, es decir, existe una relación inversa entre ese tipo de bono y las acciones (renta variable). No obstante, el bono a 2 años existe una relación positiva pero baja frente a las acciones. Tal vez, confirmando un rumor que existe en el mundo bursátil, que el bono a 2 o 3 años no es tal real como el bono a 30 años, es decir, que puede existir intervención de EEUU o de la Reserva Federal. No obstante, solo es relevante la correlación para estimar si son buenas variables para el modelo o no. Aunque INTEL tiene una correlación positiva, es inferior frente a los otros competidores.</b>
#   </p>
# </div>

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Además del análisis visual en base a la matriz de correlación, se plantearán el test de hipótesis para analizar el p-values de cada variable, frente a Apple:</p>
# </div>

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
S = df_combinado["Close_s"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, S)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y Samsung es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y Samsung es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y Samsung no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.8753519766627338
# Valor p: 0.0
# La correlación entre Apple y Samsung es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
G = df_combinado["Close_g"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, G)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y GOOGLE es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y GOOGLE es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y GOOGLE no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.9821460541603123
# Valor p: 0.0
# La correlación entre Apple y GOOGLE es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
M = df_combinado["Close_m"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, M)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y Microsoft es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y Microsoft es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y Microsoft no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.9571724416347706
# Valor p: 0.0
# La correlación entre Apple y Microsoft es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
V = df_combinado["Close_v"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, V)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y el índice VIX es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y el índice VIX es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y el índice VIX no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.4065890199355129
# Valor p: 5.507702067052019e-84
# La correlación entre Apple y el índice VIX no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
B2 = df_combinado["Close_2"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, B2)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y el Bono EEUU a 2 años es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y el Bono EEUU a 2 años es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y el Bono EEUU a 2 años no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.3658609698041717
# Valor p: 3.578182098063149e-67
# La correlación entre Apple y el Bono EEUU a 2 años no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
B30 = df_combinado["Close_30"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, B30)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y el Bono EEUU a 30 años es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y el Bono EEUU a 30 años es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y el Bono EEUU a 30 años no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: -0.19905500887697272
# Valor p: 4.133030442649836e-20
# La correlación entre Apple y el Bono EEUU a 30 años no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
I = df_combinado["Close_i"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, I)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.6
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple e INTEL es mayor que 0.6 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple e INTEL es mayor que 0.6, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple e INTEL no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.5049644122271525
# Valor p: 1.3803448153856074e-135
# La correlación entre Apple e INTEL no es mayor que 0.6 o no es estadísticamente significativa. No se rechaza la hipótesis nula.

# %%
from IPython.display import display, HTML
import pandas as pd
from scipy import stats

# Crear una lista de DataFrames para almacenar los resultados
resultados = []

# Definir las variables a comparar
variables = {
    'INTEL': I,
    'Bono EEUU a 30 años': B30,
    'Bono EEUU a 2 años': B2,
    'índice VIX': V,
    'Microsoft': M,
    'GOOGLE': G,
    'Samsung': S
}

# Calcular las correlaciones y agregar los resultados a la lista
for variable, data in variables.items():
    correlation, p_value = stats.pearsonr(X, data)
    resultado = ""

    if correlation > umbral_correlacion and p_value < alfa:
        resultado = "Correlación significativa (Se rechaza la hipótesis nula)"
    elif correlation > umbral_correlacion:
        resultado = "Correlación mayor a 0.6, pero no significativa"
    else:
        resultado = "Correlación no mayor a 0.6 o no significativa (No se rechaza la hipótesis nula)"

    resultados.append({
        'Variable': variable,
        'Coeficiente de Correlación': correlation,
        'Valor p': p_value,
        'Resultado': resultado
    })

# Crear un DataFrame a partir de la lista de resultados
resultados_df = pd.DataFrame(resultados)

# Generar el código HTML para la tabla con el formato deseado
html_table = resultados_df.to_html(classes='table-bordered', escape=False, index=False)

# Formatear el código HTML con el estilo proporcionado
styled_html = f'''
<div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
  <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Resumen del test de hipótesis sobre la correlación de Apple</h2>
  {html_table.replace('<th>Variable</th>', '<th style="color: #3f5edf;">Variable</th>').replace('<th>Coeficiente de Correlación</th>', '<th style="color: #3f5edf;">Coeficiente de Correlación</th>').replace('<th>Valor p</th>', '<th style="color: #3f5edf;">Valor p</th>').replace('<th>Resultado</th>', '<th style="color: #3f5edf;">Resultado</th>')}
</div>
'''

# Mostrar la tabla en el notebook
display(HTML(styled_html))
# Out:
# <div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
#   <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Resumen del test de hipótesis sobre la correlación de Apple</h2>
#   <table border="1" class="dataframe table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="color: #3f5edf;">Variable</th>
#       <th style="color: #3f5edf;">Coeficiente de Correlación</th>
#       <th style="color: #3f5edf;">Valor p</th>
#       <th style="color: #3f5edf;">Resultado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>INTEL</td>
#       <td>0.504964</td>
#       <td>1.380345e-135</td>
#       <td>Correlación no mayor a 0.6 o no significativa (No se rechaza la hipótesis nula)</td>
#     </tr>
#     <tr>
#       <td>Bono EEUU a 30 años</td>
#       <td>-0.199055</td>
#       <td>4.133030e-20</td>
# ...

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# A continuación se determinará si existe o no una correlación mayor a 0,7 entre GOOGLE y Apple a través del p-valor:
#   </p>
# </div>

# %%
import numpy as np
from scipy import stats

# Extrae data
X = df_combinado["Close_a"].values
G = df_combinado["Close_g"].values

# Calcula el coeficiente de correlación de Pearson y el p-valor
correlation, p_value = stats.pearsonr(X, G)

# Establece el umbral deseado para la correlación
umbral_correlacion = 0.7
alfa = 0.05  # Nivel de significancia

# Imprime los valores de correlación y p-valor
print("Coeficiente de correlación de Pearson:", correlation)
print("Valor p:", p_value)

# Compara la correlación con el umbral y el p-valor con el nivel de significancia
if correlation > umbral_correlacion and p_value < alfa:
    print("La correlación entre Apple y GOOGLE es mayor que 0.7 y es estadísticamente significativa. Se rechaza la hipótesis nula.")
elif correlation > umbral_correlacion:
    print("La correlación entre Apple y GOOGLE es mayor que 0.7, pero no es estadísticamente significativa. No se rechaza la hipótesis nula.")
else:
    print("La correlación entre Apple y GOOGLE no es mayor que 0.7 o no es estadísticamente significativa. No se rechaza la hipótesis nula.")
# Out:
# Coeficiente de correlación de Pearson: 0.9821460541603123
# Valor p: 0.0
# La correlación entre Apple y GOOGLE es mayor que 0.7 y es estadísticamente significativa. Se rechaza la hipótesis nula.

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: black;">
# Debio a que esta investigación se basa en Apple por su gran influencia en el mundo bursátil y como se demostró anteriormente, el volumen transado es bastante mayor. Apple tiene el precio histório más alto de frente a GOOGLE, Microsoft, Samsung, INTEL y el indice VIX. A través de un gráfico de línea podremos validar la hipótesis anterior.
#   </p>
# </div>

# %%
import pandas as pd
import plotly.graph_objects as go

# Leer los datos de las acciones
df = df_combinado

# Filtrar las columnas correspondientes al precio de cierre de las acciones
df_close = df[['Fecha', 'Close_g', 'Close_a', 'Close_m', 'Close_v', 'Close_i']]

# Establecer la columna 'Fecha' como el índice del dataframe
df_close.set_index('Fecha', inplace=True)

# Ordenar el dataframe por la columna de índice 'Fecha'
df_close.sort_index(inplace=True)

# Interpolar los datos para agregar más puntos
df_resampled = df_close.resample('D').interpolate()

# Obtener las fechas y los precios de cierre para cada acción
fechas = df_resampled.index
precios = df_resampled.values.T  # Transponer para obtener cada acción en una fila

# Nombres de las acciones y colores correspondientes
acciones = ['Samsung', 'Apple', 'Google', 'Microsoft', 'INTEL']
colores = ['#14299f', '#000000', '#ea4335', '#1093eb', '#0071C5']

# Crear un gráfico interactivo de líneas con Plotly
fig = go.Figure()

for i in range(len(acciones)):
    fig.add_trace(go.Scatter(x=fechas, y=precios[i], mode='lines', name=acciones[i], line=dict(color=colores[i])))

# Añadir el VIX con el color verde pistacho
fig.add_trace(go.Scatter(x=fechas, y=df_resampled['Close_v'], mode='lines', name='VIX', line=dict(color='green')))

# Personalizar el diseño del gráfico
fig.update_layout(
    title={
        'text': '<b>Precio de Cierre de Acciones<b>',
        'x': 0.5,  # Alineación horizontal central
        'y': 0.95,  # Posición vertical superior del título
        'font': {
            'color': '#3f5edf'  # Color del título
        }
    },
    xaxis_title='Fecha',
    yaxis_title='Precio de Cierre',
)

# Mostrar el gráfico interactivo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.graph_objects as go

# Leer los datos de las acciones
df = df_combinado

# Filtrar las columnas correspondientes al precio de cierre de las acciones
df_close = df[['Fecha', 'Close_g', 'Close_a', 'Close_m', 'Close_v', 'Close_i']]

# Establecer la columna 'Fecha' como el índice del dataframe
df_close.set_index('Fecha', inplace=True)

# Ordenar el dataframe por la columna de índice 'Fecha'
df_close.sort_index(inplace=True)

# Interpolar los datos para agregar más puntos
df_resampled = df_close.resample('D').interpolate()

# Obtener fechas y precios para el gráfico
fechas = df_resampled.index
precios = df_resampled.values.T  # Transponer para tener un arreglo por acción

# Definir nombres de acciones y colores
acciones = ['Google', 'Apple', 'Microsoft', 'VIX', 'INTEL']
colores = ['#ea4335', '#000000', '#1093eb', 'green', '#0071C5']

# Verificar si el número de acciones coincide con el número de colores
if len(acciones) != len(colores):
    raise ValueError("El número de acciones debe coincidir con el número de colores.")

# Crear el gráfico
fig = go.Figure()

for i in range(len(acciones)):
    fig.add_trace(go.Scatter(x=fechas, y=precios[i], mode='lines', name=acciones[i], line=dict(color=colores[i])))

# Personalizar el diseño del gráfico
fig.update_layout(
    title=dict(
        text='<b>Precio de Cierre de Acciones</b>',
        x=0.5,  # Alineación horizontal central
        y=0.95,  # Posición vertical superior del título
        font=dict(
            color='#3f5edf'  # Color del título
        )
    ),
    xaxis_title='Fecha',
    yaxis_title='Precio de Cierre',
    template='plotly_white'
)

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div id="analisis-bloque" style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: #3f5edf;">
#     <b>Si bien, en los análisis anteriores sobre el volumen transado de Apple, en este caso sobre el precio de los últimos 10 años, es Microsoft quien tiene el precio más alto. Además, se puede apreciar la co-relación estrecha que existe entre Google y Apple. A pesar de que Microsoft tiene un precio más elevado por acción, también sigue un patrón similar. No obstante, INTEL sigue un patrón diferente a las demás cotizaciones; en ocasiones se asimila, pero es menor. También es importante señalar que no se consideró el precio de Samsung, ya que está en KRW y no en dólares, lo que distorsionaría el gráfico.</b>
#   </p>
# </div>

# %%
import pandas as pd
from scipy.stats import ttest_rel
from IPython.display import HTML

# Realizar las pruebas t de Student para muestras emparejadas
t_statistic_am, p_value_am = ttest_rel(df_combinado['Close_a'], df_combinado['Close_m'])
t_statistic_ai, p_value_ai = ttest_rel(df_combinado['Close_a'], df_combinado['Close_i'])
t_statistic_ag, p_value_ag = ttest_rel(df_combinado['Close_a'], df_combinado['Close_g'])

# Interpretar los resultados
alpha = 0.05  # Nivel de significancia

# Crear una lista de diccionarios con los resultados
resultados = [
    {
        "Variable": "Apple vs. Microsoft",
        "Estadístico t": t_statistic_am,
        "Valor p": p_value_am,
        "Resultado": "Los precios de cierre de Apple son significativamente mayores que los de Microsoft." if p_value_am < alpha else "No se puede concluir que los precios de cierre de Apple sean significativamente mayores que los de Microsoft."
    },
    {
        "Variable": "Apple vs. Intel",
        "Estadístico t": t_statistic_ai,
        "Valor p": p_value_ai,
        "Resultado": "Los precios de cierre de Apple son significativamente mayores que los de Intel." if p_value_ai < alpha else "No se puede concluir que los precios de cierre de Apple sean significativamente mayores que los de Intel."
    },
    {
        "Variable": "Apple vs. Google",
        "Estadístico t": t_statistic_ag,
        "Valor p": p_value_ag,
        "Resultado": "Los precios de cierre de Apple son significativamente mayores que los de Google." if p_value_ag < alpha else "No se puede concluir que los precios de cierre de Apple sean significativamente mayores que los de Google."
    }
]

# Crear un DataFrame a partir de los resultados
df_resultados = pd.DataFrame(resultados)

# Convertir el DataFrame a una tabla HTML
html_table = df_resultados.to_html(index=False, escape=False, classes='table table-striped table-bordered')

# Formatear el código HTML con el estilo proporcionado
styled_html = f'''
<div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
  <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Resumen del test de hipótesis sobre los precios de cierre de Apple</h2>
  {html_table.replace('<th>Variable</th>', '<th style="color: #3f5edf;">Variable</th>').replace('<th>Estadístico t</th>', '<th style="color: #3f5edf;">Estadístico t</th>').replace('<th>Valor p</th>', '<th style="color: #3f5edf;">Valor p</th>').replace('<th>Resultado</th>', '<th style="color: #3f5edf;">Resultado</th>')}
</div>
'''

# Mostrar la tabla HTML formateada en Colab
display(HTML(styled_html))
# Out:
# <div style="max-width: 1200px; margin: 0 auto; text-align: center; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px; color: black;">
#   <h2 style="color: #3f5edf; font-weight: bold; font-size: 12px;">Resumen del test de hipótesis sobre los precios de cierre de Apple</h2>
#   <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="color: #3f5edf;">Variable</th>
#       <th style="color: #3f5edf;">Estadístico t</th>
#       <th style="color: #3f5edf;">Valor p</th>
#       <th style="color: #3f5edf;">Resultado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Apple vs. Microsoft</td>
#       <td>12.828285</td>
#       <td>2.577031e-36</td>
#       <td>Los precios de cierre de Apple son significativamente mayores que los de Microsoft.</td>
#     </tr>
#     <tr>
#       <td>Apple vs. Intel</td>
#       <td>32.381867</td>
# ...

# %%
import plotly.graph_objects as go
import pandas as pd

# Crear una copia del dataframe y cambiar los nombres de las columnas
df_close = df_combinado[['Close_g', 'Close_a', 'Close_m', 'Close_v', 'Close_i']]
labels = ['Google', 'Apple', 'Microsoft', 'VIX', 'INTEL']
colors = ['#ea4335', 'grey', '#1093eb', 'green', '#0071C5']

# Crear un gráfico interactivo de caja de bigotes con Plotly
fig = go.Figure()

for i in range(len(labels)):
    fig.add_trace(go.Box(y=df_close.iloc[:, i], name=labels[i], boxpoints='outliers',
                         line=dict(color='black'), fillcolor=colors[i]))

# Actualizar el diseño del gráfico
fig.update_layout(
    title={
        'text': '<b>Precio de Cierre de Acciones - Gráfico de Caja de Bigotes<b>',
        'y': 0.9,  # Ajusta la posición vertical del título
        'x': 0.5,  # Ajusta la posición horizontal del título
        'xanchor': 'center',  # Alinea el título al centro horizontalmente
        'yanchor': 'top',  # Alinea el título arriba
        'font': dict(
            size=20,  # Tamaño de la fuente
            color='#3f5edf',  # Color del texto
            family='Arial'  # Fuente
        )
    },
    yaxis_title='Precio de Cierre',
    showlegend=False
)

# Mostrar el gráfico interactivo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; text-align: left; border: 2px solid #3f5edf; border-radius: 10px; background-color: #f1f3fd; padding: 10px;">
#   <p style="text-align: justify; font-size: 12px; color: #3f5edf;">
#     <b>
#      En el gráfico de bigote, se puede apreciar que el precio medio de Apple es inferior a USD 50 y el precio máximo es X4, y al revisar la fecha de las transacciones, actualmente se encuentra en máximos historicos. Y para el caso de Microsoft, efectivamente se puede aprecia que el limite superior es cercano a 350, es decir, su precio histórico maáximo. Y la cotización más homogenea es la de INTEL, que no ha tenido bajadas muy grande y que su precio máximo no es tan alto con compración a su media historica.
#     </b>
#   </p>
# </div>
